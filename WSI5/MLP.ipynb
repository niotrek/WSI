# %%
'''
In terminal:
1. Open folder where you want to create the virtual environment
2. Run "python3 -m venv env_name" to create a virtual environment named "env_name"
3. Run "source env_name/bin/activate" to activate the virtual environment

In VSC:
1. Open Command Palette(Ctrl+Shift+P) and type "Python: Select Interpreter"
2. Select the python interpreter that you want to use
3. Select Kernel: Restart Kernel and Clear All Outputs
'''
# Out:
# '\nIn terminal:\n1. Open folder where you want to create the virtual environment\n2. Run "python3 -m venv env_name" to create a virtual environment named "env_name"\n3. Run "source env_name/bin/activate" to activate the virtual environment\n\nIn VSC:\n1. Open Command Palette(Ctrl+Shift+P) and type "Python: Select Interpreter"\n2. Select the python interpreter that you want to use\n3. Select Kernel: Restart Kernel and Clear All Outputs\n'

# %%
## Instalowanie modułów

# !pip3 install --upgrade pip

# !pip3 install -U numpy
# !pip3 install -U matplotlib
# !pip3 install -U scikit-learn
# !pip3 install -U pandas
# !pip3 install -U openpyxl
# !pip3 install -U jinja2
# Out:
# Requirement already satisfied: pip in c:\users\piotr\python\wsi5\.venv\lib\site-packages (24.0)
# Requirement already satisfied: numpy in c:\users\piotr\python\wsi5\.venv\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\piotr\python\wsi5\.venv\lib\site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\piotr\python\wsi5\.venv\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\piotr\python\wsi5\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\piotr\python\wsi5\.venv\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\piotr\python\wsi5\.venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\piotr\python\wsi5\.venv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\piotr\python\wsi5\.venv\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\piotr\python\wsi5\.venv\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\piotr\python\wsi5\.venv\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\piotr\python\wsi5\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\piotr\python\wsi5\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\piotr\python\wsi5\.venv\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\piotr\python\wsi5\.venv\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\piotr\python\wsi5\.venv\lib\site-packages (from scikit-learn) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\piotr\python\wsi5\.venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\piotr\python\wsi5\.venv\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: pandas in c:\users\piotr\python\wsi5\.venv\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\piotr\python\wsi5\.venv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\piotr\python\wsi5\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\piotr\python\wsi5\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\piotr\python\wsi5\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\piotr\python\wsi5\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: openpyxl in c:\users\piotr\python\wsi5\.venv\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\piotr\python\wsi5\.venv\lib\site-packages (from openpyxl) (1.1.0)
# Collecting jinja2
#   Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2)
#   Using cached MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#    ---------------------------------------- 0.0/133.3 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/133.3 kB ? eta -:--:--
#    -------- ------------------------------ 30.7/133.3 kB 330.3 kB/s eta 0:00:01
#    ----------------- --------------------- 61.4/133.3 kB 469.7 kB/s eta 0:00:01
#    ----------------- --------------------- 61.4/133.3 kB 469.7 kB/s eta 0:00:01
#    -------------------- ------------------ 71.7/133.3 kB 280.5 kB/s eta 0:00:01
#    -------------------- ------------------ 71.7/133.3 kB 280.5 kB/s eta 0:00:01
#    -------------------------- ------------ 92.2/133.3 kB 308.0 kB/s eta 0:00:01
#    -------------------------------------  133.1/133.3 kB 357.2 kB/s eta 0:00:01
#    -------------------------------------- 133.3/133.3 kB 328.1 kB/s eta 0:00:00
# Using cached MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl (17 kB)
# Installing collected packages: MarkupSafe, jinja2
# Successfully installed MarkupSafe-2.1.5 jinja2-3.1.4

# %%
## Importowanie modułów

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score, accuracy_score

# %%
# Sample code from scikit-learn.org

# digits = load_digits()
# print(digits.data.shape)

# plt.gray()
# plt.matshow(digits.images[0])
# plt.show()

# %%
## Przygotowanie danych

# Ładowanie danych
digits = load_digits()
X = digits.data
y = digits.target

# Normalizacja danych
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Podział danych na zbiory treningowy i testowy
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Konwersja etykiet na postać one-hot
def one_hot_encode(y, num_classes):
    one_hot = np.zeros((y.shape[0], num_classes))
    one_hot[np.arange(y.shape[0]), y] = 1
    return one_hot

y_train_one_hot = one_hot_encode(y_train, 10)
y_test_one_hot = one_hot_encode(y_test, 10)

# %%
## Funkcje aktywacji

# ReLU
def relu(x):
    return np.maximum(0, x)

def relu_derivative(x):
    return np.where(x > 0, 1, 0)

# Sigmoid
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    sx = sigmoid(x)
    return sx * (1 - sx)

# %%
def initialize_parameters(layer_dims):
    parameters = {}
    L = len(layer_dims)
    
    for l in range(1, L):
        parameters['W' + str(l)] = np.random.randn(layer_dims[l], layer_dims[l-1]) * 0.01
        parameters['b' + str(l)] = np.zeros((layer_dims[l], 1))
        
    return parameters

# %%
## Przejście do przodu

def forward_propagation(X, parameters, activation_func):
    cache = {'A0': X}
    L = len(parameters) // 2
    
    for l in range(1, L+1):
        W = parameters['W' + str(l)]
        b = parameters['b' + str(l)]
        A_prev = cache['A' + str(l-1)]
        
        Z = np.dot(W, A_prev.T) + b
        Z = Z.T
        
        if l == L:
            A = sigmoid(Z)
        else:
            A = activation_func(Z)
        
        cache['Z' + str(l)] = Z
        cache['A' + str(l)] = A
    
    return A, cache

# %%
## Przejście do tyłu

def backward_propagation(y, parameters, cache, activation_derivative):
    grads = {}
    L = len(parameters) // 2
    m = y.shape[0]
    
    dA = cache['A' + str(L)] - y
    dZ = dA * sigmoid_derivative(cache['Z' + str(L)])
    
    for l in reversed(range(1, L+1)):
        A_prev = cache['A' + str(l-1)] if l > 1 else cache['A0']
        dW = np.dot(dZ.T, A_prev) / m
        db = np.sum(dZ, axis=0, keepdims=True).T / m
        
        grads['dW' + str(l)] = dW
        grads['db' + str(l)] = db
        
        if l > 1:
            dA = np.dot(dZ, parameters['W' + str(l)])
            dZ = dA * activation_derivative(cache['Z' + str(l-1)])
    
    return grads

# %%
## SGD

def update_parameters(parameters, grads, learning_rate):
    L = len(parameters) // 2
    
    for l in range(1, L+1):
        parameters['W' + str(l)] -= learning_rate * grads['dW' + str(l)]
        parameters['b' + str(l)] -= learning_rate * grads['db' + str(l)]
    
    return parameters

# %%
## Uczenie sieci

def train(X, y, layer_dims, learning_rate=0.01, num_epochs=1000, batch_size=32, activation_func=relu, activation_derivative=relu_derivative):
    parameters = initialize_parameters(layer_dims)
    m = X.shape[0]
    
    for epoch in range(num_epochs):
        shuffled_indices = np.random.permutation(m)
        X_shuffled = X[shuffled_indices]
        y_shuffled = y[shuffled_indices]
        
        for i in range(0, m, batch_size):
            X_batch = X_shuffled[i:i+batch_size]
            y_batch = y_shuffled[i:i+batch_size]
            
            y_pred, cache = forward_propagation(X_batch, parameters, activation_func)
            grads = backward_propagation(y_batch, parameters, cache, activation_derivative)
            parameters = update_parameters(parameters, grads, learning_rate)
        
        if epoch % 100 == 0:
            predictions = np.argmax(y_pred, axis=1)
            labels = np.argmax(y_batch, axis=1)
            accuracy = accuracy_score(labels, predictions)
            f1 = f1_score(labels, predictions, average='micro')
            print(f"Epoch {epoch} - Accuracy: {accuracy:.4f}, F1 Score: {f1:.4f}")
    
    return parameters

# %%
## Ewaluacja sieci

def evaluate(X, y, parameters, activation_func):
    y_pred, _ = forward_propagation(X, parameters, activation_func)
    predictions = np.argmax(y_pred, axis=1)
    labels = np.argmax(y, axis=1)
    accuracy = accuracy_score(labels, predictions)
    f1 = f1_score(labels, predictions, average='micro')
    return accuracy, f1

# Parametry sieci
layer_dims = [64, 32, 16, 10]
learning_rate = 0.01
num_epochs = 1000
batch_size = 32

# Trenowanie sieci
parameters = train(X_train, y_train_one_hot, layer_dims, learning_rate, num_epochs, batch_size, activation_func=relu, activation_derivative=relu_derivative)

# Ewaluacja na zbiorze testowym
accuracy, f1 = evaluate(X_test, y_test_one_hot, parameters, relu)
print(f"Test Accuracy: {accuracy:.4f}, Test F1 Score: {f1:.4f}")
# Out:
# Epoch 0 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 100 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 200 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 300 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 400 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 500 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 600 - Accuracy: 0.3333, F1 Score: 0.3333
# Epoch 700 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 800 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 900 - Accuracy: 0.2222, F1 Score: 0.2222
# Test Accuracy: 0.4037, Test F1 Score: 0.4037

# %%
#eksperymenty
#badanie ilości warstw
base_dims = [64, 16, 10]
layer_dims = [base_dims[:1] + [16]*(i) + base_dims[-2:] for i in range(0, 3)]
learning_rate = 0.01
num_epochs = 1000
batch_size = 32

combined_accuracy = []
combined_f1 = []
combined_accuracy_std = []
combined_f1_std = []

for layer in layer_dims:
    model_accuracy = []
    model_f1 = []
    for i in range(0, 5):
        parameters = initialize_parameters(layer)
        print(f"Layer dims: {layer}")
        parameters = train(X_train, y_train_one_hot, layer, learning_rate, num_epochs, batch_size, activation_func=relu, activation_derivative=relu_derivative)
        accuracy, f1 = evaluate(X_test, y_test_one_hot, parameters, relu)
        print(f"Test Accuracy: {accuracy:.4f}, Test F1 Score: {f1:.4f}\n")
        model_accuracy.append(accuracy)
        model_f1.append(f1)
    print(model_accuracy)
    combined_accuracy.append(np.mean(model_accuracy))
    combined_f1.append(np.mean(model_f1))
    combined_accuracy_std.append(np.std(model_accuracy))
    combined_f1_std.append(np.std(model_f1))
# Out:
# Layer dims: [64, 16, 10]
# Epoch 0 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 100 - Accuracy: 0.7778, F1 Score: 0.7778
# Epoch 200 - Accuracy: 0.8889, F1 Score: 0.8889
# Epoch 300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 500 - Accuracy: 0.8889, F1 Score: 0.8889
# Epoch 600 - Accuracy: 0.8889, F1 Score: 0.8889
# Epoch 700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Test Accuracy: 0.9685, Test F1 Score: 0.9685
#
# Layer dims: [64, 16, 10]
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.8889, F1 Score: 0.8889
# Epoch 200 - Accuracy: 0.7778, F1 Score: 0.7778
# Epoch 300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 700 - Accuracy: 0.8889, F1 Score: 0.8889
# Epoch 800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Test Accuracy: 0.9741, Test F1 Score: 0.9741
#
# Layer dims: [64, 16, 10]
# Epoch 0 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 100 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 200 - Accuracy: 0.8889, F1 Score: 0.8889
# Epoch 300 - Accuracy: 0.8889, F1 Score: 0.8889
# Epoch 400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 600 - Accuracy: 0.8889, F1 Score: 0.8889
# Epoch 700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Test Accuracy: 0.9722, Test F1 Score: 0.9722
#
# Layer dims: [64, 16, 10]
# Epoch 0 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 100 - Accuracy: 0.7778, F1 Score: 0.7778
# Epoch 200 - Accuracy: 0.8889, F1 Score: 0.8889
# Epoch 300 - Accuracy: 0.8889, F1 Score: 0.8889
# Epoch 400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 600 - Accuracy: 0.8889, F1 Score: 0.8889
# Epoch 700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Test Accuracy: 0.9722, Test F1 Score: 0.9722
#
# Layer dims: [64, 16, 10]
# Epoch 0 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 100 - Accuracy: 0.6667, F1 Score: 0.6667
# Epoch 200 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 300 - Accuracy: 0.8889, F1 Score: 0.8889
# Epoch 400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 800 - Accuracy: 0.8889, F1 Score: 0.8889
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Test Accuracy: 0.9685, Test F1 Score: 0.9685
#
# [0.9685185185185186, 0.9740740740740741, 0.9722222222222222, 0.9722222222222222, 0.9685185185185186]
# Layer dims: [64, 16, 16, 10]
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 200 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 300 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 400 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 500 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 600 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 700 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 800 - Accuracy: 0.3333, F1 Score: 0.3333
# Epoch 900 - Accuracy: 0.1111, F1 Score: 0.1111
# Test Accuracy: 0.0926, Test F1 Score: 0.0926
#
# Layer dims: [64, 16, 16, 10]
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 200 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 300 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 400 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 500 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 600 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 700 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 800 - Accuracy: 0.3333, F1 Score: 0.3333
# Epoch 900 - Accuracy: 0.3333, F1 Score: 0.3333
# Test Accuracy: 0.1222, Test F1 Score: 0.1222
#
# Layer dims: [64, 16, 16, 10]
# Epoch 0 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 100 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 200 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 300 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 400 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 500 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 600 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 700 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 800 - Accuracy: 0.3333, F1 Score: 0.3333
# Epoch 900 - Accuracy: 0.0000, F1 Score: 0.0000
# Test Accuracy: 0.1315, Test F1 Score: 0.1315
#
# Layer dims: [64, 16, 16, 10]
# Epoch 0 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 100 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 200 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 300 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 400 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 500 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 600 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 700 - Accuracy: 0.3333, F1 Score: 0.3333
# Epoch 800 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 900 - Accuracy: 0.2222, F1 Score: 0.2222
# Test Accuracy: 0.1889, Test F1 Score: 0.1889
#
# Layer dims: [64, 16, 16, 10]
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 200 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 300 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 400 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 500 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 600 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 700 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 800 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 900 - Accuracy: 0.1111, F1 Score: 0.1111
# Test Accuracy: 0.1833, Test F1 Score: 0.1833
#
# [0.09259259259259259, 0.12222222222222222, 0.13148148148148148, 0.18888888888888888, 0.18333333333333332]
# Layer dims: [64, 16, 16, 16, 10]
# Epoch 0 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 100 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 200 - Accuracy: 0.3333, F1 Score: 0.3333
# Epoch 300 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 400 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 500 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 600 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 700 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 800 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 900 - Accuracy: 0.0000, F1 Score: 0.0000
# Test Accuracy: 0.0926, Test F1 Score: 0.0926
#
# Layer dims: [64, 16, 16, 16, 10]
# Epoch 0 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 100 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 200 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 300 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 400 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 500 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 600 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 700 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 800 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 900 - Accuracy: 0.1111, F1 Score: 0.1111
# Test Accuracy: 0.0926, Test F1 Score: 0.0926
#
# Layer dims: [64, 16, 16, 16, 10]
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 200 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 300 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 400 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 500 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 600 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 700 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 800 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 900 - Accuracy: 0.3333, F1 Score: 0.3333
# Test Accuracy: 0.0926, Test F1 Score: 0.0926
#
# Layer dims: [64, 16, 16, 16, 10]
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 200 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 300 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 400 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 500 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 600 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 700 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 800 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 900 - Accuracy: 0.0000, F1 Score: 0.0000
# Test Accuracy: 0.0926, Test F1 Score: 0.0926
#
# Layer dims: [64, 16, 16, 16, 10]
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 200 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 300 - Accuracy: 0.3333, F1 Score: 0.3333
# Epoch 400 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 500 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 600 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 700 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 800 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 900 - Accuracy: 0.1111, F1 Score: 0.1111
# Test Accuracy: 0.0926, Test F1 Score: 0.0926
#
# [0.09259259259259259, 0.09259259259259259, 0.09259259259259259, 0.09259259259259259, 0.09259259259259259]

# %%
#wykres i excel z wynikami, ilość warstw
layers = range(1, len(layer_dims)+1)

fig, axs = plt.subplots(2)

# Wykres dla Accuracy
axs[0].errorbar(layers, combined_accuracy, yerr=combined_accuracy_std, fmt='-o', ecolor='black', capsize=5) 
axs[0].set_title('Model Accuracy with Different Number of Layers')
axs[0].set_xlabel('Number of Layers')
axs[0].set_ylabel('Accuracy')

# Wykres dla F1
axs[1].errorbar(layers, combined_f1, yerr=combined_f1_std, fmt='-o', ecolor='black', color='red', capsize=5)    
axs[1].set_title('Model F1 Score with Different Number of Layers')
axs[1].set_xlabel('Number of Layers')
axs[1].set_ylabel('F1 Score')

# Wyświetl wykresy
plt.tight_layout()
plt.show()

# Zapisz wykresy
fig.savefig('layers_separate.png')

df = pd.DataFrame({
    'Accuracy': combined_accuracy,
    'F1': combined_f1,
    'Accuracy STD': combined_accuracy_std,
    'F1 STD': combined_f1_std
})


df.to_excel("model_performance_layers.xlsx", index=False)
df.to_latex("model_performance_layers.tex", index=False)

# %%
#eksperyment rozmiar batch_size
layer_dims = [64, 16, 16, 10]
batches = [8, 16, 32, 64]
learning_rate = 0.01
num_epochs = 1000
combined_accuracy = []
combined_f1 = []
combined_accuracy_std = []
combined_f1_std = []
for batch in batches:
    model_accuracy = []
    model_f1 = []
    for i in range(0, 5):
        parameters = initialize_parameters(layer_dims)
        print(f"Batch size: {batch}")
        parameters = train(X_train, y_train_one_hot, layer_dims, learning_rate, num_epochs, batch, activation_func=relu, activation_derivative=relu_derivative)
        accuracy, f1 = evaluate(X_test, y_test_one_hot, parameters, relu)
        print(f"Test Accuracy: {accuracy:.4f}, Test F1 Score: {f1:.4f}\n")
        model_accuracy.append(accuracy)
        model_f1.append(f1)
    print(model_accuracy)
    combined_accuracy.append(np.mean(model_accuracy))
    combined_f1.append(np.mean(model_f1))
    combined_accuracy_std.append(np.std(model_accuracy))
    combined_f1_std.append(np.std(model_f1))
# Out:
# Batch size: 8
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 200 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 400 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Test Accuracy: 0.9685, Test F1 Score: 0.9685
#
# Batch size: 8
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 200 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 400 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Test Accuracy: 0.9611, Test F1 Score: 0.9611
#
# Batch size: 8
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 200 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Test Accuracy: 0.9667, Test F1 Score: 0.9667
#
# Batch size: 8
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 200 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 300 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Test Accuracy: 0.9685, Test F1 Score: 0.9685
#
# Batch size: 8
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 200 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 300 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 400 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Test Accuracy: 0.9667, Test F1 Score: 0.9667
#
# [0.9685185185185186, 0.9611111111111111, 0.9666666666666667, 0.9685185185185186, 0.9666666666666667]
# Batch size: 16
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 200 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 300 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 400 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 500 - Accuracy: 0.5556, F1 Score: 0.5556
# Epoch 600 - Accuracy: 0.3333, F1 Score: 0.3333
# Epoch 700 - Accuracy: 0.3333, F1 Score: 0.3333
# Epoch 800 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 900 - Accuracy: 0.7778, F1 Score: 0.7778
# Test Accuracy: 0.8722, Test F1 Score: 0.8722
#
# Batch size: 16
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 200 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 300 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 400 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 500 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 600 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 700 - Accuracy: 0.4444, F1 Score: 0.4444
# Epoch 800 - Accuracy: 0.6667, F1 Score: 0.6667
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Test Accuracy: 0.8889, Test F1 Score: 0.8889
#
# Batch size: 16
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 200 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 300 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 400 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 500 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 600 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 700 - Accuracy: 0.5556, F1 Score: 0.5556
# Epoch 800 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 900 - Accuracy: 0.7778, F1 Score: 0.7778
# Test Accuracy: 0.8407, Test F1 Score: 0.8407
#
# Batch size: 16
# Epoch 0 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 100 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 200 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 300 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 400 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 500 - Accuracy: 0.3333, F1 Score: 0.3333
# Epoch 600 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 700 - Accuracy: 0.5556, F1 Score: 0.5556
# Epoch 800 - Accuracy: 0.7778, F1 Score: 0.7778
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Test Accuracy: 0.8241, Test F1 Score: 0.8241
#
# Batch size: 16
# Epoch 0 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 100 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 200 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 300 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 400 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 500 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 600 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 700 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 800 - Accuracy: 0.6667, F1 Score: 0.6667
# Epoch 900 - Accuracy: 0.8889, F1 Score: 0.8889
# Test Accuracy: 0.8889, Test F1 Score: 0.8889
#
# [0.8722222222222222, 0.8888888888888888, 0.8407407407407408, 0.8240740740740741, 0.8888888888888888]
# Batch size: 32
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 200 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 300 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 400 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 500 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 600 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 700 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 800 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 900 - Accuracy: 0.2222, F1 Score: 0.2222
# Test Accuracy: 0.2093, Test F1 Score: 0.2093
#
# Batch size: 32
# Epoch 0 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 100 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 200 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 300 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 400 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 500 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 600 - Accuracy: 0.3333, F1 Score: 0.3333
# Epoch 700 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 800 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 900 - Accuracy: 0.1111, F1 Score: 0.1111
# Test Accuracy: 0.0926, Test F1 Score: 0.0926
#
# Batch size: 32
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.3333, F1 Score: 0.3333
# Epoch 200 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 300 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 400 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 500 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 600 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 700 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 800 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 900 - Accuracy: 0.0000, F1 Score: 0.0000
# Test Accuracy: 0.0926, Test F1 Score: 0.0926
#
# Batch size: 32
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 200 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 300 - Accuracy: 0.3333, F1 Score: 0.3333
# Epoch 400 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 500 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 600 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 700 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 800 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 900 - Accuracy: 0.0000, F1 Score: 0.0000
# Test Accuracy: 0.0963, Test F1 Score: 0.0963
#
# Batch size: 32
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 200 - Accuracy: 0.1111, F1 Score: 0.1111
# Epoch 300 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 400 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 500 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 600 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 700 - Accuracy: 0.3333, F1 Score: 0.3333
# Epoch 800 - Accuracy: 0.2222, F1 Score: 0.2222
# Epoch 900 - Accuracy: 0.0000, F1 Score: 0.0000
# Test Accuracy: 0.2519, Test F1 Score: 0.2519
#
# [0.20925925925925926, 0.09259259259259259, 0.09259259259259259, 0.0962962962962963, 0.2518518518518518]
# Batch size: 64
# Epoch 0 - Accuracy: 0.1707, F1 Score: 0.1707
# Epoch 100 - Accuracy: 0.0488, F1 Score: 0.0488
# Epoch 200 - Accuracy: 0.0976, F1 Score: 0.0976
# Epoch 300 - Accuracy: 0.1220, F1 Score: 0.1220
# Epoch 400 - Accuracy: 0.1707, F1 Score: 0.1707
# Epoch 500 - Accuracy: 0.0976, F1 Score: 0.0976
# Epoch 600 - Accuracy: 0.1463, F1 Score: 0.1463
# Epoch 700 - Accuracy: 0.1707, F1 Score: 0.1707
# Epoch 800 - Accuracy: 0.1220, F1 Score: 0.1220
# Epoch 900 - Accuracy: 0.1463, F1 Score: 0.1463
# Test Accuracy: 0.0926, Test F1 Score: 0.0926
#
# Batch size: 64
# Epoch 0 - Accuracy: 0.1463, F1 Score: 0.1463
# Epoch 100 - Accuracy: 0.1951, F1 Score: 0.1951
# Epoch 200 - Accuracy: 0.0976, F1 Score: 0.0976
# Epoch 300 - Accuracy: 0.0976, F1 Score: 0.0976
# Epoch 400 - Accuracy: 0.1220, F1 Score: 0.1220
# Epoch 500 - Accuracy: 0.1220, F1 Score: 0.1220
# Epoch 600 - Accuracy: 0.0976, F1 Score: 0.0976
# Epoch 700 - Accuracy: 0.1220, F1 Score: 0.1220
# Epoch 800 - Accuracy: 0.0976, F1 Score: 0.0976
# Epoch 900 - Accuracy: 0.1220, F1 Score: 0.1220
# Test Accuracy: 0.0926, Test F1 Score: 0.0926
#
# Batch size: 64
# Epoch 0 - Accuracy: 0.0488, F1 Score: 0.0488
# Epoch 100 - Accuracy: 0.1220, F1 Score: 0.1220
# Epoch 200 - Accuracy: 0.1463, F1 Score: 0.1463
# Epoch 300 - Accuracy: 0.0244, F1 Score: 0.0244
# Epoch 400 - Accuracy: 0.0732, F1 Score: 0.0732
# Epoch 500 - Accuracy: 0.0976, F1 Score: 0.0976
# Epoch 600 - Accuracy: 0.0488, F1 Score: 0.0488
# Epoch 700 - Accuracy: 0.0732, F1 Score: 0.0732
# Epoch 800 - Accuracy: 0.0732, F1 Score: 0.0732
# Epoch 900 - Accuracy: 0.1951, F1 Score: 0.1951
# Test Accuracy: 0.0926, Test F1 Score: 0.0926
#
# Batch size: 64
# Epoch 0 - Accuracy: 0.1220, F1 Score: 0.1220
# Epoch 100 - Accuracy: 0.1707, F1 Score: 0.1707
# Epoch 200 - Accuracy: 0.1220, F1 Score: 0.1220
# Epoch 300 - Accuracy: 0.0976, F1 Score: 0.0976
# Epoch 400 - Accuracy: 0.1463, F1 Score: 0.1463
# Epoch 500 - Accuracy: 0.0488, F1 Score: 0.0488
# Epoch 600 - Accuracy: 0.1220, F1 Score: 0.1220
# Epoch 700 - Accuracy: 0.0976, F1 Score: 0.0976
# Epoch 800 - Accuracy: 0.0732, F1 Score: 0.0732
# Epoch 900 - Accuracy: 0.0976, F1 Score: 0.0976
# Test Accuracy: 0.0926, Test F1 Score: 0.0926
#
# Batch size: 64
# Epoch 0 - Accuracy: 0.0488, F1 Score: 0.0488
# Epoch 100 - Accuracy: 0.0976, F1 Score: 0.0976
# Epoch 200 - Accuracy: 0.1220, F1 Score: 0.1220
# Epoch 300 - Accuracy: 0.0732, F1 Score: 0.0732
# Epoch 400 - Accuracy: 0.1220, F1 Score: 0.1220
# Epoch 500 - Accuracy: 0.0976, F1 Score: 0.0976
# Epoch 600 - Accuracy: 0.0976, F1 Score: 0.0976
# Epoch 700 - Accuracy: 0.0732, F1 Score: 0.0732
# Epoch 800 - Accuracy: 0.0488, F1 Score: 0.0488
# Epoch 900 - Accuracy: 0.1220, F1 Score: 0.1220
# Test Accuracy: 0.0926, Test F1 Score: 0.0926
#
# [0.09259259259259259, 0.09259259259259259, 0.09259259259259259, 0.09259259259259259, 0.09259259259259259]

# %%
fig, axs = plt.subplots(2)

# Wykres dla Accuracy
axs[0].errorbar(batches, combined_accuracy, yerr=combined_accuracy_std, fmt='-o', ecolor='black', capsize=5)
axs[0].set_title('Model Accuracy with Different Batch Sizes')
axs[0].set_xlabel('Batch Size')
axs[0].set_ylabel('Accuracy')

# Wykres dla F1
axs[1].errorbar(batches, combined_f1, yerr=combined_f1_std, fmt='-x', ecolor='black', color='red', capsize=5)
axs[1].set_title('Model F1 Score with Different Batch Sizes')
axs[1].set_xlabel('Batch Size')
axs[1].set_ylabel('F1 Score')

# Wyświetl wykresy
plt.tight_layout()
plt.show()

# Zapisz wykresy
fig.savefig('batch_size_separate.png')


df = pd.DataFrame({
    'Accuracy': combined_accuracy,
    'F1': combined_f1,
    'Accuracy STD': combined_accuracy_std,
    'F1 STD': combined_f1_std
})


df.to_excel("model_performance_batch_size.xlsx", index=False)

df.to_latex("model_performance_batch_size.tex", index=False)

# %%
activation_functions = ['sigmoid', 'relu']

layer_dims = [64, 16, 10]
batch_size = 8
learning_rate = 0.01
num_epochs = 2000
combined_accuracy = []
combined_f1 = []
combined_accuracy_std = []
combined_f1_std = []

for activation in activation_functions:
    parameters = initialize_parameters(layer_dims)
    model_accuracy = []
    model_f1 = []
    for i in range(0,5):
        if activation == 'sigmoid':
            parameters = train(X_train, y_train_one_hot, layer_dims, learning_rate, num_epochs, batch_size, activation_func=sigmoid, activation_derivative=sigmoid_derivative)
        else:
            parameters = train(X_train, y_train_one_hot, layer_dims, learning_rate, num_epochs, batch_size, activation_func=relu, activation_derivative=relu_derivative)
        accuracy, f1 = evaluate(X_test, y_test_one_hot, parameters, relu)
        print(f"{activation}: Test Accuracy: {accuracy:.4f}, Test F1 Score: {f1:.4f}\n")
        model_accuracy.append(accuracy)
        model_f1.append(f1)
    print(model_accuracy)
    combined_accuracy.append(np.mean(model_accuracy))
    combined_f1.append(np.mean(model_f1))
    combined_accuracy_std.append(np.std(model_accuracy))
    combined_f1_std.append(np.std(model_f1))
# Out:
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 200 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1000 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1100 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1200 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1900 - Accuracy: 1.0000, F1 Score: 1.0000
# sigmoid: Test Accuracy: 0.9148, Test F1 Score: 0.9148
#
# Epoch 0 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 100 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 200 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 500 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1000 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1100 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1200 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1600 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 1700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1900 - Accuracy: 1.0000, F1 Score: 1.0000
# sigmoid: Test Accuracy: 0.9185, Test F1 Score: 0.9185
#
# Epoch 0 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 100 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 200 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1000 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1100 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1200 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1900 - Accuracy: 1.0000, F1 Score: 1.0000
# sigmoid: Test Accuracy: 0.9296, Test F1 Score: 0.9296
#
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 200 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 300 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1000 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1100 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1200 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1900 - Accuracy: 1.0000, F1 Score: 1.0000
# sigmoid: Test Accuracy: 0.9296, Test F1 Score: 0.9296
#
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 200 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1000 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1100 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1200 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1900 - Accuracy: 1.0000, F1 Score: 1.0000
# sigmoid: Test Accuracy: 0.9111, Test F1 Score: 0.9111
#
# [0.9148148148148149, 0.9185185185185185, 0.9296296296296296, 0.9296296296296296, 0.9111111111111111]
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 200 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1000 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1100 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1200 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1900 - Accuracy: 1.0000, F1 Score: 1.0000
# relu: Test Accuracy: 0.9741, Test F1 Score: 0.9741
#
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 200 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1000 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1100 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1200 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1900 - Accuracy: 1.0000, F1 Score: 1.0000
# relu: Test Accuracy: 0.9741, Test F1 Score: 0.9741
#
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 200 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1000 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1100 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1200 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1900 - Accuracy: 1.0000, F1 Score: 1.0000
# relu: Test Accuracy: 0.9815, Test F1 Score: 0.9815
#
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 200 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1000 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1100 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1200 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1900 - Accuracy: 1.0000, F1 Score: 1.0000
# relu: Test Accuracy: 0.9778, Test F1 Score: 0.9778
#
# Epoch 0 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 100 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 200 - Accuracy: 0.0000, F1 Score: 0.0000
# Epoch 300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 900 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1000 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1100 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1200 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1300 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1400 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1500 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1600 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1700 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1800 - Accuracy: 1.0000, F1 Score: 1.0000
# Epoch 1900 - Accuracy: 1.0000, F1 Score: 1.0000
# relu: Test Accuracy: 0.9815, Test F1 Score: 0.9815
#
# [0.9740740740740741, 0.9740740740740741, 0.9814814814814815, 0.9777777777777777, 0.9814814814814815]

# %%
#tabele badanie funkcji aktywacji

df = pd.DataFrame({
    'Accuracy': combined_accuracy,
    'F1': combined_f1,
    'Accuracy STD': combined_accuracy_std,
    'F1 STD': combined_f1_std
})


df.to_excel("model_performance_activation.xlsx", index=False)

df.to_latex("model_performance_activation.tex", index=False)
